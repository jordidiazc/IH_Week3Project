# %%
import pandas as pd
import numpy as np
df = pd.read_csv('athletes.csv')
df
# Out:
#         athlete_id             name               region  \
# 0           2554.0        Pj Ablang           South West
# 1           3517.0    Derek Abdella                  NaN
# 2           4691.0              NaN                  NaN
# 3           5164.0      Abo Brandon  Southern California
# 4           5286.0      Bryce Abbey                  NaN
# ...            ...              ...                  ...
# 423001    574489.0       Odo Renata        Latin America
# 423002    585696.0    Lozzie Trevor            Australia
# 423003    608828.0    Marisol Smith           North West
# 423004    628881.0  Pedrini Morgane               Europe
# 423005    631847.0       Eden Kenny  Northern California
#
#                            team              affiliate  gender   age  height  \
# 0                   Double Edge   Double Edge CrossFit    Male  24.0    70.0
# 1                           NaN                    NaN    Male  42.0    70.0
# ...

# %%
df.columns
# Out:
# Index(['athlete_id', 'name', 'region', 'team', 'affiliate', 'gender', 'age',
#        'height', 'weight', 'fran', 'helen', 'grace', 'filthy50', 'fgonebad',
#        'run400', 'run5k', 'candj', 'snatch', 'deadlift', 'backsq', 'pullups',
#        'eat', 'train', 'background', 'experience', 'schedule', 'howlong'],
#       dtype='object')

# %%
df.nunique()
# Out:
# athlete_id    423003
# name          306752
# region            17
# team            4532
# affiliate       9778
# gender             3
# age               52
# height           127
# weight           386
# fran            1041
# helen           1064
# grace            874
# filthy50        2069
# fgonebad         547
# run400           402
# run5k           1779
# candj            428
# snatch           372
# deadlift         629
# backsq           568
# pullups          178
# eat               47
# train             83
# background        43
# experience        84
# schedule         134
# howlong           30
# dtype: int64

# %%
df['fgonebad'].value_counts()
# Out:
# fgonebad
# 0.0      3033
# 301.0     307
# 300.0     274
# 305.0     239
# 308.0     229
#          ...
# 786.0       1
# 103.0       1
# 96.0        1
# 580.0       1
# 700.0       1
# Name: count, Length: 547, dtype: int64

# %%
def clean_spaces(df):
    df.columns = df.columns.str.replace(" ", "")
    return df
clean_spaces(df)
# Out:
#         athlete_id             name               region  \
# 0           2554.0        Pj Ablang           South West
# 1           3517.0    Derek Abdella                  NaN
# 2           4691.0              NaN                  NaN
# 3           5164.0      Abo Brandon  Southern California
# 4           5286.0      Bryce Abbey                  NaN
# ...            ...              ...                  ...
# 423001    574489.0       Odo Renata        Latin America
# 423002    585696.0    Lozzie Trevor            Australia
# 423003    608828.0    Marisol Smith           North West
# 423004    628881.0  Pedrini Morgane               Europe
# 423005    631847.0       Eden Kenny  Northern California
#
#                            team              affiliate  gender   age  height  \
# 0                   Double Edge   Double Edge CrossFit    Male  24.0    70.0
# 1                           NaN                    NaN    Male  42.0    70.0
# ...

# %%
db = df.copy()

# %%
df.drop(columns=["athlete_id","name","team","affiliate","fgonebad","run400","eat","background","experience","schedule","howlong","grace","helen"], inplace = True)

# %%
df.dropna(how='all',inplace = True)

# %%
df.dropna(thresh=10,inplace = True)

# %%
df.replace(0, np.nan,inplace = True)

# %%
df.dropna(thresh=10,inplace = True)

# %%
df.replace('--', np.nan, inplace=True)

# %%
df.dropna(subset=['gender'],inplace=True)

# %%
df
# Out:
#         athlete_id             name               region  \
# 0           2554.0        Pj Ablang           South West
# 1           3517.0    Derek Abdella                  NaN
# 2           4691.0              NaN                  NaN
# 3           5164.0      Abo Brandon  Southern California
# 4           5286.0      Bryce Abbey                  NaN
# ...            ...              ...                  ...
# 423001    574489.0       Odo Renata        Latin America
# 423002    585696.0    Lozzie Trevor            Australia
# 423003    608828.0    Marisol Smith           North West
# 423004    628881.0  Pedrini Morgane               Europe
# 423005    631847.0       Eden Kenny  Northern California
#
#                            team              affiliate  gender   age  height  \
# 0                   Double Edge   Double Edge CrossFit    Male  24.0    70.0
# 1                           NaN                    NaN    Male  42.0    70.0
# ...

# %%
uu = db['train'].unique()
uu
# Out:
# array(['I workout mostly at a CrossFit Affiliate|I have a coach who determines my programming|I record my workouts|',
#        'I workout mostly at a CrossFit Affiliate|I incorporate CrossFit.com workouts|I write my own programming|I record my workouts|',
#        'I workout mostly at a CrossFit Affiliate|I record my workouts|',
#        'I workout mostly at a CrossFit Affiliate|I write my own programming|I record my workouts|',
#        nan,
#        'I workout mostly at a CrossFit Affiliate|I incorporate CrossFit.com workouts|',
#        'I workout mostly at a CrossFit Affiliate|',
#        'I workout mostly at home, work, or a traditional gym|I incorporate CrossFit.com workouts|I record my workouts|',
#        'I workout mostly at a CrossFit Affiliate|I have a coach who determines my programming|',
#        'I workout mostly at home, work, or a traditional gym|I have a coach who determines my programming|I record my workouts|',
# ...

# %%
df = df[ df['train'].isna() == False].reset_index(drop=True)

# %%
df['Affiliate'] = df['train'].apply(lambda x: search_keyword(x, "CrossFit Affiliate"))

# %%
dd = db.copy

# %%
db
# Out:
#                     region  gender   age  height  weight   fran  filthy50  \
# 0      Southern California    Male  40.0    67.0     NaN  211.0       NaN
# 1                      NaN    Male  32.0    65.0   149.0  206.0    1053.0
# 2                      NaN    Male  40.0    68.0   177.0  205.0    1647.0
# 3                      NaN    Male  31.0    65.0   150.0  119.0     971.0
# 4               North East    Male  42.0    72.0   210.0  198.0       NaN
# ...                    ...     ...   ...     ...     ...    ...       ...
# 58079           South West    Male  25.0    70.0   163.0    NaN       NaN
# 58080            Australia    Male  24.0    70.0   174.0    NaN       NaN
# 58081        Latin America  Female  25.0    64.0   126.0  659.0    2443.0
# 58082        North Central  Female  22.0    72.0   174.0    NaN       NaN
# 58083         Central East  Female  19.0    60.0   145.0    NaN       NaN
#
#         run5k  candj  snatch  deadlift  backsq  pullups  \
# ...

# %%
df=df.dropna(subset=['region']) .reset_index(drop=True)

# %%
df
# Out:
#        athlete_id             name               region  \
# 0          2554.0        Pj Ablang           South West
# 1          5164.0      Abo Brandon  Southern California
# 2          6610.0    Anthony Abeel        South Central
# 3         13285.0      Kipp Abbott         Central East
# 4         21053.0    Douglas Acker           North East
# ...           ...              ...                  ...
# 76269    541626.0  Abbigayle Kline         Central East
# 76270    577268.0   Yoenesha Ortiz           South West
# 76271    604551.0          Amy Yin  Southern California
# 76272    518427.0       Sadaf Mian           North East
# 76273    628881.0  Pedrini Morgane               Europe
#
#                                  team                  affiliate  gender  \
# 0                         Double Edge       Double Edge CrossFit    Male
# 1                        LAX CrossFit               LAX CrossFit    Male
# ...

# %%
import matplotlib.pyplot as plt
from collections import Counter

conteo = db['region'].value_counts()
elementos = list( conteo.index )
frecuencias = list( conteo.values )

fig, ax = plt.subplots()
ax.barh(elementos, frecuencias, color='skyblue', label=frecuencias);

# %%
import seaborn as sns

# %%
conteo_df = pd.DataFrame(conteo).reset_index()
def color_func(region):
    if region in ["North East", "South East", "North Central", "Mid Atlantic","South Central", "Central East", "Southern California", "South West", "North West", "Northern California"]:
        return 'blue'
    if region in ["Europe"]
    else:
        return 'skyblue'
conteo_df['color'] = conteo_df['region'].apply(color_func)
fig, ax = plt.subplots(figsize=(5,5))
sns.barplot(data=conteo_df, x='count', y='region', color='skyblue')
for bar, color in zip(ax.patches, conteo_df['color']):
    bar.set_color(color)
#fig.savefig("1F1.png")
# Out:
#   Cell In[279], line 5
#     if region in ["Europe"]
#                            ^
# SyntaxError: expected ':'

# %%
ddd=db.copy

# %%
def xyx(region):
    if region in ["North East", "South East", "North Central", "Mid Atlantic", "South Central", "Central East", 
                  "Southern California", "South West", "North West", "Northern California"]:
        return 'USA'
    elif region == "Europe":
        return 'Europe'
    else:
        return np.nan
df['EU/NA'] = df['region'].apply(xyx)
print(conteo_dd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[413], line 10
#       8         return np.nan
#       9 df['EU/NA'] = df['region'].apply(xyx)
# ---> 10 print(conteo_dd)
#
# NameError: name 'conteo_dd' is not defined

# %%
db
# Out:
#                     region  gender   age  height  weight   fran  filthy50  \
# 0      Southern California    Male  40.0    67.0     NaN  211.0       NaN
# 1               North East    Male  42.0    72.0   210.0  198.0       NaN
# 2      Southern California    Male  30.0    71.0   200.0  243.0       NaN
# 3                   Africa    Male  28.0    70.0   176.0  720.0       NaN
# 4               North East    Male  35.0    68.0   225.0  215.0    1594.0
# ...                    ...     ...   ...     ...     ...    ...       ...
# 46074           South West    Male  25.0    70.0   163.0    NaN       NaN
# 46075            Australia    Male  24.0    70.0   174.0    NaN       NaN
# 46076        Latin America  Female  25.0    64.0   126.0  659.0    2443.0
# 46077        North Central  Female  22.0    72.0   174.0    NaN       NaN
# 46078         Central East  Female  19.0    60.0   145.0    NaN       NaN
#
#         run5k  candj  snatch  deadlift  backsq  pullups  \
# ...

# %%
db['EU/NA'].value_counts()
# Out:
# EU/NA
# USA       33209
# Europe     4430
# Name: count, dtype: int64

# %%
df=df.dropna(subset=['EU/NA']).reset_index()

# %%
df
# Out:
#        index  athlete_id             name               region  \
# 0          0      2554.0        Pj Ablang           South West
# 1          1      5164.0      Abo Brandon  Southern California
# 2          2      6610.0    Anthony Abeel        South Central
# 3          3     13285.0      Kipp Abbott         Central East
# 4          4     21053.0    Douglas Acker           North East
# ...      ...         ...              ...                  ...
# 61870  76269    541626.0  Abbigayle Kline         Central East
# 61871  76270    577268.0   Yoenesha Ortiz           South West
# 61872  76271    604551.0          Amy Yin  Southern California
# 61873  76272    518427.0       Sadaf Mian           North East
# 61874  76273    628881.0  Pedrini Morgane               Europe
#
#                                  team                  affiliate  gender  \
# 0                         Double Edge       Double Edge CrossFit    Male
# ...

# %%
usa_data = db[db['EU/NA'] == 'USA']
europe_data = db[db['EU/NA'] == 'Europe']

# Contar la cantidad de cada género en cada categoría
usa_gender_counts = usa_data['gender'].value_counts()
europe_gender_counts = europe_data['gender'].value_counts()
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Gráfico para "USA"
axs[0].pie(usa_gender_counts, labels=usa_gender_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen'])
axs[0].set_title('Gender Distribution in USA')

# Gráfico para "Europe"
axs[1].pie(europe_gender_counts, labels=europe_gender_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen'])
axs[1].set_title('Gender Distribution in Europe')
fig.savefig("2.png")
# Mostrar los gráficos
plt.show()

# %%
usa_data = db[db['EU/NA'] == 'USA']
europe_data = db[db['EU/NA'] == 'Europe']

# Contar la cantidad de cada género en cada categoría
usa_gender_counts = usa_data['Affiliate'].value_counts()
europe_gender_counts = europe_data['Affiliate'].value_counts()
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Gráfico para "USA"
axs[0].pie(usa_gender_counts, labels=usa_gender_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen'])
axs[0].set_title('Train in Affiliate Crossfit in USA')

# Gráfico para "Europe"
axs[1].pie(europe_gender_counts, labels=europe_gender_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen'])
axs[1].set_title('Train in Affiliate Crossfit in Europe')
fig.savefig("3.png")
# Mostrar los gráficos
plt.show()

# %%
dlc = db.copy

# %%
df['Male'] = df['gender'].replace('Female', np.nan)

# %%
db
# Out:
#        index               region  gender   age  height  weight   fran  \
# 0          0  Southern California    Male  40.0    67.0     NaN  211.0
# 1          1           North East    Male  42.0    72.0   210.0  198.0
# 2          2  Southern California    Male  30.0    71.0   200.0  243.0
# 3          4           North East    Male  35.0    68.0   225.0  215.0
# 4          5        North Central    Male  36.0    71.0   199.0  284.0
# ...      ...                  ...     ...   ...     ...     ...    ...
# 37634  46071           North West    Male  24.0     NaN     NaN  336.0
# 37635  46073           South West    Male  39.0    75.0   186.0  980.0
# 37636  46074           South West    Male  25.0    70.0   163.0    NaN
# 37637  46077        North Central  Female  22.0    72.0   174.0    NaN
# 37638  46078         Central East  Female  19.0    60.0   145.0    NaN
#
#        filthy50   run5k  candj  snatch  deadlift  backsq  pullups  \
# ...

# %%
df=df.dropna(subset=['Male'])

# %%
db
# Out:
#        index               region gender   age  height  weight   fran  \
# 0          0  Southern California   Male  40.0    67.0     NaN  211.0
# 1          1           North East   Male  42.0    72.0   210.0  198.0
# 2          2  Southern California   Male  30.0    71.0   200.0  243.0
# 3          4           North East   Male  35.0    68.0   225.0  215.0
# 4          5        North Central   Male  36.0    71.0   199.0  284.0
# ...      ...                  ...    ...   ...     ...     ...    ...
# 37632  46069           South East   Male  42.0    69.0   230.0    NaN
# 37633  46070               Europe   Male  33.0    71.0   170.0    NaN
# 37634  46071           North West   Male  24.0     NaN     NaN  336.0
# 37635  46073           South West   Male  39.0    75.0   186.0  980.0
# 37636  46074           South West   Male  25.0    70.0   163.0    NaN
#
#        filthy50   run5k  candj  snatch  deadlift  backsq        pullups  \
# ...

# %%
palette = {
    'USA': 'lightblue',
    'Europe': 'lightgreen'}
# Crear el gráfico de barras con la media de "run5k" para "Europe" y "USA"
plt.figure(figsize=(8, 6))
sns.barplot(data=db, x='EU/NA', y='snatch', ci=None, estimator=np.mean, palette=palette)
plt.title('Weightlifting: Snatch')
plt.xlabel('Region')
plt.ylabel('Pounds')
plt.savefig("OUTLIERS.png")
plt.show()
# Out:
# C:\Users\thege\AppData\Local\Temp\ipykernel_24896\3247303986.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=db, x='EU/NA', y='snatch', ci=None, estimator=np.mean, palette=palette)
# C:\Users\thege\AppData\Local\Temp\ipykernel_24896\3247303986.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=db, x='EU/NA', y='snatch', ci=None, estimator=np.mean, palette=palette)

# %%
Q1 = df['pullups'].quantile(0.25)
Q3 = df['pullups'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
db_cleaned8 = df[(df['pullups'] >= lower_bound) & (df['pullups'] <= upper_bound)]
